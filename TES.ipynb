# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error


time_series = np.array([
    [735.], [330.], [560.], [750.], [730.], [450.], [600.], [450.], [555.], [600.], [400.], [800.]
])


train_data = time_series[:11].flatten()
test_data = time_series[11:].flatten()


result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 1
forecasted_values = result_ets.forecast(steps=n_forecast)


plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(12, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()


mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 164220.02759589913
# Mean Absolute Error (MAE): 405.240703281271
# Percentage Error: 50.65508791015888

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error


time_series = np.array([
    [735.], [330.], [560.], [750.], [730.], [450.], [600.], [450.], [555.], [600.], [400.], [800.]
])


train_data = time_series[:10].flatten()
test_data = time_series[10:].flatten()


result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 2
forecasted_values = result_ets.forecast(steps=n_forecast)


plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(11, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()


mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 86574.09705552926
# Mean Absolute Error (MAE): 274.9999979856457
# Percentage Error: 45.0226284690766

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error


time_series = np.array([
    [735.], [330.], [560.], [750.], [730.], [450.], [600.], [450.], [555.], [600.], [400.], [800.]
])


train_data = time_series[:9].flatten()
test_data = time_series[9:].flatten()


result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 3
forecasted_values = result_ets.forecast(steps=n_forecast)

plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(10, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()

mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 66631.04167397301
# Mean Absolute Error (MAE): 232.7577106381791
# Percentage Error: 36.6389236047644

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Chuỗi thời gian đã cho
time_series = np.array([
    [735.], [330.], [560.], [750.], [730.], [450.], [600.], [450.], [555.], [600.], [400.], [800.]
])


train_data = time_series[:8].flatten()
test_data = time_series[8:].flatten()


result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 4
forecasted_values = result_ets.forecast(steps=n_forecast)


plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(9, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()


mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 41156.94805728982
# Mean Absolute Error (MAE): 191.03937452277034
# Percentage Error: 32.247727298088215

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error


time_series = np.array([
    [68.], [31.], [58.], [77.], [75.], [46.], [62.], [46.], [57.], [62.], [41.], [82.]
])


train_data = time_series[:11].flatten()
test_data = time_series[11:].flatten()

result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 1
forecasted_values = result_ets.forecast(steps=n_forecast)


plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(12, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()


mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 1599.9998213990323
# Mean Absolute Error (MAE): 39.99999776748784
# Percentage Error: 48.78048508230224

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error


time_series = np.array([
    [68.], [31.], [58.], [77.], [75.], [46.], [62.], [46.], [57.], [62.], [41.], [82.]
])


train_data = time_series[:10].flatten()
test_data = time_series[10:].flatten()


result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 2
forecasted_values = result_ets.forecast(steps=n_forecast)


plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(11, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()


mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 887.3599347207378
# Mean Absolute Error (MAE): 28.499999777723843
# Percentage Error: 46.84963402713031

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error


time_series = np.array([
    [68.], [31.], [58.], [77.], [75.], [46.], [62.], [46.], [57.], [62.], [41.], [82.]
])


train_data = time_series[:9].flatten()
test_data = time_series[9:].flatten()


result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()


n_forecast = 3
forecasted_values = result_ets.forecast(steps=n_forecast)

# Tạo biểu đồ để hiển thị chuỗi thời gian, dự đoán và giá trị thực tế
plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(10, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()

# So sánh với giá trị thực tế
mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 619.0123714118514
# Mean Absolute Error (MAE): 23.42861154400286
# Percentage Error: 37.37034033030056

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Chuỗi thời gian đã cho
time_series = np.array([
    [68.], [31.], [58.], [77.], [75.], [46.], [62.], [46.], [57.], [62.], [41.], [82.]
])

# Sử dụng 10 điểm đầu tiên để phân tách và dự đoán 2 điểm tiếp theo
train_data = time_series[:8].flatten()
test_data = time_series[8:].flatten()

# Phân tách chuỗi thời gian bằng mô hình ETS
result_ets = ExponentialSmoothing(train_data, trend='add', seasonal='add', seasonal_periods=4).fit()

# Dự đoán giá trị trong tương lai (2 điểm tiếp theo)
n_forecast = 4
forecasted_values = result_ets.forecast(steps=n_forecast)

# Tạo biểu đồ để hiển thị chuỗi thời gian, dự đoán và giá trị thực tế
plt.plot(np.arange(1, 13), time_series, label='Actual')
plt.plot(np.arange(9, 13), forecasted_values, label='Forecast', linestyle='dashed', marker='o')
plt.legend()
plt.show()

# So sánh với giá trị thực tế
mse = mean_squared_error(test_data, forecasted_values)
mae = mean_absolute_error(test_data, forecasted_values)
percentage_error = np.mean(np.abs((test_data - forecasted_values) / test_data)) * 100

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Percentage Error:", percentage_error)
# Out:
# Mean Squared Error (MSE): 9525.021666818117
# Mean Absolute Error (MAE): 91.37495217839748
# Percentage Error: 152.04748872589354
